# %%
import pandas as pd
import numpy as np
laptop = pd.read_csv(r'./assets/data/laptop-price.csv')

# %%
laptop.head()
# Out:
#     brand processor_brand processor_name processor_gnrtn ram_gb ram_type
# 0    ASUS           Intel        Core i3            10th   4 GB     DDR4  \
# 1  Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2  Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3    ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4    ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
#
#       ssd      hdd       os  os_bit graphic_card_gb  weight     warranty
# 0    0 GB  1024 GB  Windows  64-bit            0 GB  Casual  No warranty  \
# 1    0 GB  1024 GB  Windows  64-bit            0 GB  Casual  No warranty
# 2    0 GB  1024 GB  Windows  64-bit            0 GB  Casual  No warranty
# 3  512 GB     0 GB  Windows  32-bit            2 GB  Casual  No warranty
# 4    0 GB   512 GB  Windows  64-bit            0 GB  Casual  No warranty
#
#   Touchscreen msoffice  Price   rating  Number of Ratings  Number of Reviews
# 0          No       No  34649  2 stars                  3                  0
# 1          No       No  38999  3 stars                 65                  5
# 2          No       No  39999  3 stars                  8                  1
# 3          No       No  69990  3 stars                  0                  0
# 4          No       No  26990  3 stars                  0                  0

# %% [markdown]
# cleansing

# %%
# processor_gnrtn
laptop['processor_gnrtn'].replace('Not Available', np.nan, inplace=True)

# %%
# menghilangkan th dibelakang gen procie
laptop['processor_gnrtn'] =laptop['processor_gnrtn'].str.rstrip("th")
laptop['ram_gb'] =laptop['ram_gb'].str.rstrip("GB")
laptop['ssd'] =laptop['ssd'].str.rstrip("GB")
laptop['hdd'] =laptop['hdd'].str.rstrip("GB")
laptop['graphic_card_gb'] =laptop['graphic_card_gb'].str.rstrip("GB")

# %%
laptop['warranty'] = laptop['warranty'].str.replace("No warranty", "0 year")
laptop
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type
# 0      ASUS           Intel        Core i3              10     4      DDR4  \
# 1    Lenovo           Intel        Core i3              10     4      DDR4
# 2    Lenovo           Intel        Core i3              10     4      DDR4
# 3      ASUS           Intel        Core i5              10     8      DDR4
# 4      ASUS           Intel   Celeron Dual             NaN     4      DDR4
# ..      ...             ...            ...             ...    ...      ...
# 818    ASUS             AMD        Ryzen 9             NaN     4      DDR4
# 819    ASUS             AMD        Ryzen 9             NaN     4      DDR4
# 820    ASUS             AMD        Ryzen 9             NaN     4      DDR4
# 821    ASUS             AMD        Ryzen 9             NaN     4      DDR4
# 822  Lenovo             AMD        Ryzen 5              10     8      DDR4
#
#        ssd    hdd       os  os_bit graphic_card_gb      weight warranty
# 0       0   1024   Windows  64-bit              0       Casual   0 year  \
# 1       0   1024   Windows  64-bit              0       Casual   0 year
# 2       0   1024   Windows  64-bit              0       Casual   0 year
# 3     512      0   Windows  32-bit              2       Casual   0 year
# 4       0    512   Windows  64-bit              0       Casual   0 year
# ..     ...    ...      ...     ...             ...         ...      ...
# 818  1024      0   Windows  64-bit              0       Casual   1 year
# 819  1024      0   Windows  64-bit              0       Casual   1 year
# 820  1024      0   Windows  64-bit              4       Casual   1 year
# 821  1024      0   Windows  64-bit              4       Casual   1 year
# 822   512      0       DOS  64-bit              0   ThinNlight   0 year
#
#     Touchscreen msoffice   Price   rating  Number of Ratings
# 0            No       No   34649  2 stars                  3  \
# 1            No       No   38999  3 stars                 65
# 2            No       No   39999  3 stars                  8
# 3            No       No   69990  3 stars                  0
# 4            No       No   26990  3 stars                  0
# ..          ...      ...     ...      ...                ...
# 818          No       No  135990  3 stars                  0
# 819          No       No  144990  3 stars                  0
# 820          No       No  149990  3 stars                  0
# 821          No       No  142990  3 stars                  0
# 822          No       No   57490  4 stars                 18
#
#      Number of Reviews
# 0                    0
# 1                    5
# 2                    1
# 3                    0
# 4                    0
# ..                 ...
# 818                  0
# 819                  0
# 820                  0
# 821                  0
# 822                  4
#
# [823 rows x 19 columns]

# %%
laptop['Touchscreen'] = laptop['Touchscreen'].replace({'No': "False", "Yes": "True"})

# %%
laptop['msoffice'] = laptop['msoffice'].replace({'No': "False", "Yes": "True"})

# %%
def convert_to_rupiah(price):
    price_in_rupiah = price * 180
    return f'{price_in_rupiah}'

laptop['Price'] = laptop['Price'].apply(convert_to_rupiah)
laptop
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type
# 0      ASUS           Intel        Core i3              10     4      DDR4  \
# 1    Lenovo           Intel        Core i3              10     4      DDR4
# 2    Lenovo           Intel        Core i3              10     4      DDR4
# 3      ASUS           Intel        Core i5              10     8      DDR4
# 4      ASUS           Intel   Celeron Dual             NaN     4      DDR4
# ..      ...             ...            ...             ...    ...      ...
# 818    ASUS             AMD        Ryzen 9             NaN     4      DDR4
# 819    ASUS             AMD        Ryzen 9             NaN     4      DDR4
# 820    ASUS             AMD        Ryzen 9             NaN     4      DDR4
# 821    ASUS             AMD        Ryzen 9             NaN     4      DDR4
# 822  Lenovo             AMD        Ryzen 5              10     8      DDR4
#
#        ssd    hdd       os  os_bit graphic_card_gb      weight warranty
# 0       0   1024   Windows  64-bit              0       Casual   0 year  \
# 1       0   1024   Windows  64-bit              0       Casual   0 year
# 2       0   1024   Windows  64-bit              0       Casual   0 year
# 3     512      0   Windows  32-bit              2       Casual   0 year
# 4       0    512   Windows  64-bit              0       Casual   0 year
# ..     ...    ...      ...     ...             ...         ...      ...
# 818  1024      0   Windows  64-bit              0       Casual   1 year
# 819  1024      0   Windows  64-bit              0       Casual   1 year
# 820  1024      0   Windows  64-bit              4       Casual   1 year
# 821  1024      0   Windows  64-bit              4       Casual   1 year
# 822   512      0       DOS  64-bit              0   ThinNlight   0 year
#
#     Touchscreen msoffice     Price   rating  Number of Ratings
# 0         False    False   6236820  2 stars                  3  \
# 1         False    False   7019820  3 stars                 65
# 2         False    False   7199820  3 stars                  8
# 3         False    False  12598200  3 stars                  0
# 4         False    False   4858200  3 stars                  0
# ..          ...      ...       ...      ...                ...
# 818       False    False  24478200  3 stars                  0
# 819       False    False  26098200  3 stars                  0
# 820       False    False  26998200  3 stars                  0
# 821       False    False  25738200  3 stars                  0
# 822       False    False  10348200  4 stars                 18
#
#      Number of Reviews
# 0                    0
# 1                    5
# 2                    1
# 3                    0
# 4                    0
# ..                 ...
# 818                  0
# 819                  0
# 820                  0
# 821                  0
# 822                  4
#
# [823 rows x 19 columns]

# %%
laptop['rating'] = laptop['rating'].str.rstrip("stars")
laptop
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type
# 0      ASUS           Intel        Core i3              10     4      DDR4  \
# 1    Lenovo           Intel        Core i3              10     4      DDR4
# 2    Lenovo           Intel        Core i3              10     4      DDR4
# 3      ASUS           Intel        Core i5              10     8      DDR4
# 4      ASUS           Intel   Celeron Dual             NaN     4      DDR4
# ..      ...             ...            ...             ...    ...      ...
# 818    ASUS             AMD        Ryzen 9             NaN     4      DDR4
# 819    ASUS             AMD        Ryzen 9             NaN     4      DDR4
# 820    ASUS             AMD        Ryzen 9             NaN     4      DDR4
# 821    ASUS             AMD        Ryzen 9             NaN     4      DDR4
# 822  Lenovo             AMD        Ryzen 5              10     8      DDR4
#
#        ssd    hdd       os  os_bit graphic_card_gb      weight warranty
# 0       0   1024   Windows  64-bit              0       Casual   0 year  \
# 1       0   1024   Windows  64-bit              0       Casual   0 year
# 2       0   1024   Windows  64-bit              0       Casual   0 year
# 3     512      0   Windows  32-bit              2       Casual   0 year
# 4       0    512   Windows  64-bit              0       Casual   0 year
# ..     ...    ...      ...     ...             ...         ...      ...
# 818  1024      0   Windows  64-bit              0       Casual   1 year
# 819  1024      0   Windows  64-bit              0       Casual   1 year
# 820  1024      0   Windows  64-bit              4       Casual   1 year
# 821  1024      0   Windows  64-bit              4       Casual   1 year
# 822   512      0       DOS  64-bit              0   ThinNlight   0 year
#
#     Touchscreen msoffice     Price rating  Number of Ratings
# 0         False    False   6236820     2                   3  \
# 1         False    False   7019820     3                  65
# 2         False    False   7199820     3                   8
# 3         False    False  12598200     3                   0
# 4         False    False   4858200     3                   0
# ..          ...      ...       ...    ...                ...
# 818       False    False  24478200     3                   0
# 819       False    False  26098200     3                   0
# 820       False    False  26998200     3                   0
# 821       False    False  25738200     3                   0
# 822       False    False  10348200     4                  18
#
#      Number of Reviews
# 0                    0
# 1                    5
# 2                    1
# 3                    0
# 4                    0
# ..                 ...
# 818                  0
# 819                  0
# 820                  0
# 821                  0
# 822                  4
#
# [823 rows x 19 columns]

# %%
laptop.dtypes
# Out:
# brand                object
# processor_brand      object
# processor_name       object
# processor_gnrtn      object
# ram_gb               object
# ram_type             object
# ssd                  object
# hdd                  object
# os                   object
# os_bit               object
# graphic_card_gb      object
# weight               object
# warranty             object
# Touchscreen          object
# msoffice             object
# Price                object
# rating               object
# Number of Ratings     int64
# Number of Reviews     int64
# dtype: object

# %%
# laptop['processor_gnrtn'] = pd.to_numeric(laptop['processor_gnrtn'])
mean_laptop_procie_gen = round(laptop['processor_gnrtn'].astype(float).mean())
print(mean_laptop_procie_gen)
laptop['processor_gnrtn'].replace(np.nan, mean_laptop_procie_gen, inplace=True)
# Out:
# 10

# %%
int_columns = ['ram_gb', 'ssd','hdd', 'graphic_card_gb', 'Price', 'Number of Ratings', 'Number of Reviews',]
laptop[int_columns] = laptop[int_columns].apply(pd.to_numeric)

# %%
laptop['processor_gnrtn'] = pd.to_numeric(laptop['processor_gnrtn'])

# %%
laptop['warranty'].value_counts()
# Out:
# warranty
# 1 year     509
# 0 year     278
# 2 years     23
# 3 years     13
# Name: count, dtype: int64

# %%
laptop['warranty'] = laptop['warranty'].str.rstrip("year")
laptop['warranty']
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#        ..
# 818    1
# 819    1
# 820    1
# 821    1
# 822    0
# Name: warranty, Length: 823, dtype: object

# %%
laptop['warranty'] = laptop['warranty'].str.rstrip("years")
laptop.head(30)
# Out:
#      brand processor_brand processor_name  processor_gnrtn  ram_gb ram_type
# 0     ASUS           Intel        Core i3               10       4     DDR4  \
# 1   Lenovo           Intel        Core i3               10       4     DDR4
# 2   Lenovo           Intel        Core i3               10       4     DDR4
# 3     ASUS           Intel        Core i5               10       8     DDR4
# 4     ASUS           Intel   Celeron Dual               10       4     DDR4
# 5     ASUS           Intel   Celeron Dual               10       4     DDR4
# 6     ASUS           Intel   Celeron Dual               10       4     DDR4
# 7     ASUS           Intel        Core i5               10       8     DDR4
# 8   Lenovo           Intel        Core i5               10       4     DDR4
# 9     acer             AMD        Ryzen 5               10       4     DDR4
# 10    acer             AMD        Ryzen 5               10       4     DDR4
# 11    acer             AMD        Ryzen 5               10       4     DDR4
# 12   Avita           Intel   Celeron Dual               10       4     DDR4
# 13    ASUS           Intel   Celeron Dual               10       4     DDR4
# 14    ASUS           Intel        Core i3               11       4     DDR4
# 15      HP           Intel        Core i3               11       8     DDR4
# 16      HP           Intel        Core i5               11       8     DDR4
# 17  Lenovo           Intel   Celeron Dual               10       4     DDR4
# 18      HP           Intel   Celeron Dual               10       8     DDR4
# 19  Lenovo           Intel   Celeron Dual               10       4     DDR4
# 20    ASUS           Intel   Celeron Dual               10       4     DDR4
# 21    ASUS           Intel   Celeron Dual               10       4     DDR4
# 22      HP           Intel        Core i3                7       4     DDR4
# 23      HP           Intel        Core i5                7       4     DDR4
# 24    ASUS           Intel        Core i3               11       4     DDR4
# 25  Lenovo           Intel        Core i3               10       8     DDR4
# 26    ASUS           Intel        Core i3               11       4     DDR4
# 27    ASUS           Intel        Core i3               10       8     DDR4
# 28      HP           Intel        Core i3               11       8     DDR4
# 29    DELL           Intel        Core i3               10       8     DDR4
#
#     ssd   hdd       os  os_bit  graphic_card_gb      weight warranty
# 0     0  1024  Windows  64-bit                0      Casual       0   \
# 1     0  1024  Windows  64-bit                0      Casual       0
# 2     0  1024  Windows  64-bit                0      Casual       0
# 3   512     0  Windows  32-bit                2      Casual       0
# 4     0   512  Windows  64-bit                0      Casual       0
# 5     0   512  Windows  64-bit                0      Casual       0
# 6     0   512  Windows  32-bit                0      Casual       0
# 7     0  1024  Windows  32-bit                2      Casual       0
# 8     0  1024  Windows  32-bit                0      Casual       0
# 9     0   512  Windows  32-bit                4      Casual       0
# 10    0   512  Windows  32-bit                6      Casual       0
# 11    0   512  Windows  32-bit                4      Casual       0
# 12    0   512  Windows  64-bit                0      Casual       0
# 13    0   512  Windows  64-bit                0      Casual       0
# 14  256     0  Windows  64-bit                0      Casual       0
# 15  256     0  Windows  64-bit                0      Casual       1
# 16  256     0  Windows  64-bit                0      Casual       1
# 17  256     0  Windows  64-bit                0  ThinNlight       0
# 18  256     0  Windows  64-bit                0  ThinNlight       0
# 19  256     0  Windows  64-bit                0  ThinNlight       0
# 20  256     0  Windows  64-bit                0      Casual       0
# 21    0  1024  Windows  64-bit                0      Casual       1
# 22    0  1024  Windows  64-bit                0      Casual       0
# 23    0  1024  Windows  32-bit                2      Casual       0
# 24  256     0  Windows  64-bit                0  ThinNlight       0
# 25  256     0  Windows  32-bit                0  ThinNlight       2
# 26  256     0  Windows  32-bit                0      Casual       1
# 27  256     0  Windows  64-bit                0  ThinNlight       0
# 28  256     0  Windows  64-bit                0  ThinNlight       1
# 29  256     0  Windows  64-bit                0  ThinNlight       1
#
#    Touchscreen msoffice     Price rating  Number of Ratings  Number of Reviews
# 0        False    False   6236820     2                   3                  0
# 1        False    False   7019820     3                  65                  5
# 2        False    False   7199820     3                   8                  1
# 3        False    False  12598200     3                   0                  0
# 4        False    False   4858200     3                   0                  0
# 5        False    False   4138200     3                   0                  0
# 6        False    False   3958200     3                  31                  3
# 7        False    False  10583820     3                   0                  0
# 8        False    False   8999820     3                   0                  0
# 9        False    False  10798200     4                1946                240
# 10       False    False  16866000     4                 259                 47
# 11       False    False  13138200     4                 425                 67
# 12       False    False   3148200     3                1120                196
# 13       False    False   4138200     3                   0                  0
# 14       False    False   6478200     3                   0                  0
# 15        True    False  10168200     3                   0                  0
# 16       False    False  11770200     3                   0                  0
# 17       False    False   5759820     4                 286                 19
# 18       False    False   5848200     4                  58                  6
# 19       False    False   5723820     3                   0                  0
# 20       False    False   5380200     4                   7                  0
# 21       False    False   4318200     3               15279               1947
# 22       False    False   5931900     4                 311                 27
# 23       False    False   8316000     4                  47                  7
# 24       False    False   6197220     4                  37                  6
# 25       False     True   6838200     4                2080                235
# 26       False     True   6478200     4                1479                181
# 27       False    False   6116400     4                  67                  3
# 28       False     True   7198200     4                 273                 30
# 29       False     True   7108200     4                1267                171

# %%
laptop['rating'] = pd.to_numeric(laptop['rating'])

# %%
laptop['warranty'] = pd.to_numeric(laptop['warranty'])

# %%
laptop['brand'].replace("acer", "Acer", inplace=True)

# %%
laptop.dtypes
# Out:
# brand                object
# processor_brand      object
# processor_name       object
# processor_gnrtn       int64
# ram_gb                int64
# ram_type             object
# ssd                   int64
# hdd                   int64
# os                   object
# os_bit               object
# graphic_card_gb       int64
# weight               object
# warranty              int64
# Touchscreen          object
# msoffice             object
# Price                 int64
# rating                int64
# Number of Ratings     int64
# Number of Reviews     int64
# dtype: object

# %%
laptop.rename(columns={'Touchscreen': "touchscreen", "Price": "price", "Number of Ratings": "no_ratings", "Number of Reviews": "no_reviews"}, inplace=True)

# %%
laptop.to_excel('./assets/data/laptop-price.xlsx', index=None, header=True)
